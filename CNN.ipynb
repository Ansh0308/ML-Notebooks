# %%
path = r'/content/images.jpeg'
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter
import numpy as np
from scipy.ndimage.filters import convolve
# Out:
# /tmp/ipython-input-1561192354.py:7: DeprecationWarning: Please import `convolve` from the `scipy.ndimage` namespace; the `scipy.ndimage.filters` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.filters import convolve

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
#kernel declaration
identity=np.array([[0,0,0],[0,1,0],[0,0,0]])
blur=np.ones((7,7),dtype=float)*(1/7)
horizontal=np.array([[1,1,1],[0,0,0],[-1,-1,-1]])

# %%
kernel=horizontal
img2=convolve(img,kernel)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=300x168>
