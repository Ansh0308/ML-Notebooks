# %%
import numpy as np

# %%
a=np.array([[1,2],[3,4]])
print(a)
# Out:
# [[1 2]
#  [3 4]]

# %%
a=np.array(['a','b','c'])
print(a)
# Out:
# ['a' 'b' 'c']

# %%
import pandas as pd

# %%
pd.Series(a)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
data={'name':['ansh','harsh','kaushal'],
      'roll':[1,2,3],
      }

# %%
pd.DataFrame(data)
# Out:
#       name  roll
# 0     ansh     1
# 1    harsh     2
# 2  kaushal     3

# %%
np.random.rand(3,2)
# Out:
# array([[0.12583267, 0.43698901],
#        [0.43325747, 0.34949306],
#        [0.68649791, 0.76146161]])

# %%
data=pd.DataFrame(np.random.randn(5,3))
data
# Out:
#           0         1         2
# 0 -1.307393 -0.134965  1.289904
# 1 -0.500052 -0.082302  0.448975
# 2  0.037294 -1.090131  0.046313
# 3  1.952355  2.146286 -0.851807
# 4  0.591509 -0.914030  0.213094

# %%
data=pd.DataFrame(np.random.randn(5,3),index=['a','c','d','f','h'],columns=['one','two','three'])
data
# Out:
#         one       two     three
# a -0.118088  0.236743 -0.937809
# c  1.803990 -1.147067  1.234047
# d -0.520447 -0.590383  0.882509
# f  0.174548 -0.787987 -1.202681
# h -0.223147  0.659736 -0.106391

# %%
data=data.reindex(['a','b','c','d','e','f','g','h'])
data
# Out:
#         one       two     three
# a -0.118088  0.236743 -0.937809
# b       NaN       NaN       NaN
# c  1.803990 -1.147067  1.234047
# d -0.520447 -0.590383  0.882509
# e       NaN       NaN       NaN
# f  0.174548 -0.787987 -1.202681
# g       NaN       NaN       NaN
# h -0.223147  0.659736 -0.106391

# %%
data['three'].isnull()
# Out:
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# g     True
# h    False
# Name: three, dtype: bool

# %%
data.dropna()
data.fillna(data.mean())
# Out:
#         one       two     three
# a -0.118088  0.236743 -0.937809
# b  0.223371 -0.325791 -0.026065
# c  1.803990 -1.147067  1.234047
# d -0.520447 -0.590383  0.882509
# e  0.223371 -0.325791 -0.026065
# f  0.174548 -0.787987 -1.202681
# g  0.223371 -0.325791 -0.026065
# h -0.223147  0.659736 -0.106391

# %%
data.fillna(method='pad')
# Out:
# /tmp/ipython-input-27-3355551220.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='pad')
#         one       two     three
# a -0.118088  0.236743 -0.937809
# b -0.118088  0.236743 -0.937809
# c  1.803990 -1.147067  1.234047
# d -0.520447 -0.590383  0.882509
# e -0.520447 -0.590383  0.882509
# f  0.174548 -0.787987 -1.202681
# g  0.174548 -0.787987 -1.202681
# h -0.223147  0.659736 -0.106391

# %%
data.fillna(method='bfill')
# Out:
# /tmp/ipython-input-28-1397359497.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill')
#         one       two     three
# a -0.118088  0.236743 -0.937809
# b  1.803990 -1.147067  1.234047
# c  1.803990 -1.147067  1.234047
# d -0.520447 -0.590383  0.882509
# e  0.174548 -0.787987 -1.202681
# f  0.174548 -0.787987 -1.202681
# g -0.223147  0.659736 -0.106391
# h -0.223147  0.659736 -0.106391

# %%
data.describe()
# Out:
#             one       two     three
# count  5.000000  5.000000  5.000000
# mean   0.223371 -0.325791 -0.026065
# std    0.917875  0.749306  1.076516
# min   -0.520447 -1.147067 -1.202681
# 25%   -0.223147 -0.787987 -0.937809
# 50%   -0.118088 -0.590383 -0.106391
# 75%    0.174548  0.236743  0.882509
# max    1.803990  0.659736  1.234047
